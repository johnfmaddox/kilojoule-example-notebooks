# %% [markdown]
# # Example 9.2: Otto Cycle
#
# *John F. Maddox, Ph.D., P.E.<br>
# University of Kentucky - Paducah Campus<br>
# ME 321: Engineering Thermodynamics II<br>*

# %% [markdown]
# ## Problem Statement
# An Otto cycle with compression ratio of $8$ starts its compression stroke from $p_1=1\ \text{bar}$, $T_1=300\ \text{K}$.  The maximum temperature after combustion is $1200\ \text{K}$.
# Determine:
# * (a) $p$-$v$ diagram
# * (b) $T$-$s$ diagram
# * (c) $T$,$p$ at each state
# * (d) $q_{in}$
# * (e) $w_{net}$
# * (f) $\eta_{th}$

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074244&node=10465167&a=685460354&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_K import *

air = realfluid.Properties('Air', unit_system='SI_K')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
# %%showcalc
# T[1] = Quantity(300,'K')
# p[1] = Quantity(1,'bar')
# T_max = Quantity(1200,'K')
# r = Quantity(8,'')
# Out:
# \begin{align}
#   {T}_{ 1 } &=  300\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 1 } &=  1\ \mathrm{bar}  = 100.0\ \mathrm{kPa}
# \end{align}
#
# \begin{align}
#   T_{max} &=  1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   r &=  8
# \end{align}

# %% [markdown]
# ### Assumptions
#   - Treat air as a real fluid
#   - Variable Specific Heat

# %% [markdown]
# #### (c) $T$,$p$ at each state

# %%
# %%showcalc
# r"Isentropic Compression $1\to2$"
# s[1] = air.s(T=T[1],p=p[1])
# v[1] = air.v(T=T[1],p=p[1])
# v[2] = v[1]/r
# s[2] = s[1]
# T[2] = air.T(s=s[2],v=v[2])
# p[2] = air.p(s=s[2],v=v[2])
#
# r"Isochoric Heat Addition $2\to3$"
# v[3] = v[2]
# T[3] = T_max
# p[3] = air.p(T=T[3],v=v[3])
#
# r"Isentropic Expansion $3\to4$"
# s[3] = air.s(T=T[3],v=v[3])
# s[4] = s[3]
# v[4] = r*v[3]
# T[4] = air.T(v=v[4],s=s[4])
# p[4] = air.p(v=v[4],s=s[4])
# Out:
# Isentropic Compression $1\to2$
# \begin{align}
#   {s}_{ 1 } &=  \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 100.0\ \mathrm{kPa} \right) = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {v}_{ 1 } &=  \mathrm{ \underset{ air }{ v } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ v } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 100.0\ \mathrm{kPa} \right) = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {v}_{ 2 } &=  \frac{ {v}_{ 1 } }{ r } \\
#     &= \frac{ 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 8 }\\
#     &= 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {s}_{ 2 } &=  {s}_{ 1 }  = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {T}_{ 2 } &=  \mathrm{ \underset{ air }{ T } }\left( \mathrm{ s } = {s}_{ 2 }, \mathrm{ v } = {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ T } }\left( \mathrm{ s } = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 675.53\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 2 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ s } = {s}_{ 2 }, \mathrm{ v } = {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ s } = 3.8905\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 1814.1\ \mathrm{kPa}
# \end{align}
#
# Isochoric Heat Addition $2\to3$
# \begin{align}
#   {v}_{ 3 } &=  {v}_{ 2 }  = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 3 } &=  T_{max}  = 1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 3 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ v } = {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 3229.4\ \mathrm{kPa}
# \end{align}
#
# Isentropic Expansion $3\to4$
# \begin{align}
#   {s}_{ 3 } &=  \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ v } = {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ s } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ v } = 0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {s}_{ 4 } &=  {s}_{ 3 }  = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {v}_{ 4 } &=   r  \cdot  {v}_{ 3 }  \\
#     &=  8  \cdot  0.10761\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \\
#     &= 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 4 } &=  \mathrm{ \underset{ air }{ T } }\left( \mathrm{ v } = {v}_{ 4 }, \mathrm{ s } = {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ T } }\left( \mathrm{ v } = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, \mathrm{ s } = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 577.77\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 4 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ v } = {v}_{ 4 }, \mathrm{ s } = {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ v } = 0.86088\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, \mathrm{ s } = 4.3702\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 192.78\ \mathrm{kPa}
# \end{align}

# %% [markdown]
# #### (a) $p$-$v$ diagram

# %% [markdown]
# ##### Linear Scale

# %%
pv = air.pv_diagram()
for i in [1,2,3,4]:
    pv.plot_state(states[i],label_loc='east')
pv.plot_process(states[1],states[2], path='isentropic',label='isentropic',pos=.8)
pv.plot_process(states[2],states[3], path='isochoric')
pv.plot_process(states[3],states[4], path='isentropic',label='isentropic')
pv.plot_process(states[4],states[1], path='isochoric');

pv.plot_isotherm(T[3])
pv.plot_isotherm(T[1],pos=.1);

# %% [markdown]
# ##### Log-Log Scale

# %%
pv = air.pv_diagram(log_x=True,log_y=True)
for i in [1,2,3,4]:
    pv.plot_state(states[i],label_loc='east')
pv.plot_process(states[1],states[2], path='isentropic',label='isentropic',pos=.8)
pv.plot_process(states[2],states[3], path='isochoric')
pv.plot_process(states[3],states[4], path='isentropic',label='isentropic')
pv.plot_process(states[4],states[1], path='isochoric');

pv.plot_isotherm(T[3])
pv.plot_isotherm(T[1],pos=.1);

# %% [markdown]
# #### (b) $T$-$s$ diagram

# %%
Ts = air.Ts_diagram()
for i in [1,2,3,4]:
    Ts.plot_state(states[i], label_loc='north east')
Ts.plot_process(states[1],states[2], path='isentropic')
Ts.plot_process(states[2],states[3], path='isochoric',label='isochoric')
Ts.plot_process(states[3],states[4], path='isentropic')
Ts.plot_process(states[4],states[1], path='isochoric',label='isochoric');

Ts.plot_isobar(p[3],pos=.1)
Ts.plot_isobar(p[1]);

# %% [markdown]
# #### (d) $q_{in}$

# %%
# %%showcalc
# r"Heat transfer only takes place from $2\to3$ and from $4\to1$"
# u[2] = air.u(T=T[2],p=p[2])
# u[3] = air.u(T=T[3],p=p[3])
#
# q_2_to_3 = u[3]-u[2]
# q_in = q_2_to_3
# Out:
# Heat transfer only takes place from $2\to3$ and from $4\to1$
# \begin{align}
#   {u}_{ 2 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 2 }, \mathrm{ p } = {p}_{ 2 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 675.53\ \mathrm{K}, \mathrm{ p } = 1814.1\ \mathrm{kPa} \right) = 618.43\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {u}_{ 3 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ p } = {p}_{ 3 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ p } = 3229.4\ \mathrm{kPa} \right) = 1059.0\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{2\to{}3} &=   {u}_{ 3 } - {u}_{ 2 }  \\
#     &=  1059.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 618.43\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{in} &=  q_{2\to{}3}  = 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (e) $w_{net}$

# %%
# %%showcalc
# u[1] = air.u(T=T[1],p=p[1])
# u[4] = air.u(T=T[4],p=p[4])
# q_4_to_1 = u[4]-u[1]
# q_out = q_4_to_1
#
# "First law for cycle"
# w_net = q_in-q_out
# Out:
# \begin{align}
#   {u}_{ 1 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 1 }, \mathrm{ p } = {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 300\ \mathrm{K}, \mathrm{ p } = 100.0\ \mathrm{kPa} \right) = 340.21\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {u}_{ 4 } &=  \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = {T}_{ 4 }, \mathrm{ p } = {p}_{ 4 } \right)  = \mathrm{ \underset{ air }{ u } }\left( \mathrm{ T } = 577.77\ \mathrm{K}, \mathrm{ p } = 192.78\ \mathrm{kPa} \right) = 544.12\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{4\to{}1} &=   {u}_{ 4 } - {u}_{ 1 }  \\
#     &=  544.12\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 340.21\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{out} &=  q_{4\to{}1}  = 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# First law for cycle
# \begin{align}
#   w_{net} &=   q_{in} - q_{out}  \\
#     &=  440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 203.91\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (f)  $\eta_{th}$

# %%
# %%showcalc
# "Thermal efficiency"
# eta_th = w_net/q_in
# Out:
# Thermal efficiency
# \begin{align}
#   \eta_{th} &=  \frac{ w_{net} }{ q_{in} } \\
#     &= \frac{ 236.62\ \frac{\mathrm{kJ}}{\mathrm{kg}} }{ 440.53\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\
#     &= 0.53712
# \end{align}

# %%
Summary()
Summary(['q_in','w_net','eta_th']);

# %%
# Export your solution to submit to Canvas
# 1) Ensure all cells above show your final solution
# 2) Click the 'Save' button in the toolbar
# 3) Uncomment (remove the #) from the last line in this cell
# 4) Ensure the filename in the command below matches the filename of this notebook
# 4) Execute this cell to create an HTML file showing only the output 
# 5) Submit the .html file located in the folder with this notebook

# !jupyter nbconvert --to html_embed --no-input --no-prompt "Ex9.2 Otto Cycle (Real-Fluid).ipynb"
# Out:
# [NbConvertApp] Converting notebook Ex9.2 Otto Cycle (Real-Fluid).ipynb to html_embed
# [NbConvertApp] Writing 1117358 bytes to Ex9.2 Otto Cycle (Real-Fluid).html
