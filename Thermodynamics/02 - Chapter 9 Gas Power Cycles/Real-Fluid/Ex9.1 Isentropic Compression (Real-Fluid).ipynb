# %% [markdown]
# ## Problem Statement
# Air is compressed isentropically form $T_1=250\ \text{K}$, $p_1=1\ \text{bar}$ to $T_2=400\ \text{K}$
# * (a) What is the compression ratio
# * (b) What is the final pressure

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074239&node=10465156&a=1753145453&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_C import *

# This treats the air as a "real fluid", i.e. not an ideal gas
air = realfluid.Properties('Air', unit_system='SI_C')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
# %%showcalc
# T[1] = Quantity(250,'K')
# p[1] = Quantity(1,'bar')
# T[2] = Quantity(400,'K')
# Out:
# \begin{align}
#   {T}_{ 1 } &=  250\ \mathrm{K}  = -23.15\ \mathrm{°C}
# \end{align}
#
# \begin{align}
#   {p}_{ 1 } &=  1\ \mathrm{bar}  = 100.0\ \mathrm{kPa}
# \end{align}
#
# \begin{align}
#   {T}_{ 2 } &=  400\ \mathrm{K}  = 126.85\ \mathrm{°C}
# \end{align}

# %% [markdown]
# #### Assumptions (Real Fluid)
# * Not Ideal Gas
# * Variable specific heat
# * Adiabatic
# * Negligible changes in kinetic and potential energies

# %% [markdown]
# #### (a) Compression Ratio

# %%
# %%showcalc
# "Properties at inlet"
# v[1] = air.v(T[1],p[1])
# s[1] = air.s(T[1],p[1])
#
# "Isentropic"
# s[2] = s[1]
#
# "Specific volume at exit"
# v[2] = air.v(T[2],s[2])
#
# "Compression ratio"
# r = v[1]/v[2]
# Out:
# Properties at inlet
# \begin{align}
#   {v}_{ 1 } &=  \mathrm{ \underset{ air }{ v } }\left( {T}_{ 1 }, {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ v } }\left( -23.15\ \mathrm{°C}, 100.0\ \mathrm{kPa} \right) = 0.71694\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {s}_{ 1 } &=  \mathrm{ \underset{ air }{ s } }\left( {T}_{ 1 }, {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ s } }\left( -23.15\ \mathrm{°C}, 100.0\ \mathrm{kPa} \right) = 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# Isentropic
# \begin{align}
#   {s}_{ 2 } &=  {s}_{ 1 }  = 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# Specific volume at exit
# \begin{align}
#   {v}_{ 2 } &=  \mathrm{ \underset{ air }{ v } }\left( {T}_{ 2 }, {s}_{ 2 } \right)  = \mathrm{ \underset{ air }{ v } }\left( 126.85\ \mathrm{°C}, 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 0.22172\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# Compression ratio
# \begin{align}
#   r &=  \frac{ {v}_{ 1 } }{ {v}_{ 2 } } \\
#     &= \frac{ 0.71694\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 0.22172\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\\
#     &= 3.2335
# \end{align}

# %% [markdown]
# #### (b) Final Pressure

# %%
# %%showcalc
# "Pressure at exit"
# p[2] = air.p(T[2],s[2])
#
# "Pressure ratio"
# r_p = p[2]/p[1]
# Out:
# Pressure at exit
# \begin{align}
#   {p}_{ 2 } &=  \mathrm{ \underset{ air }{ p } }\left( {T}_{ 2 }, {s}_{ 2 } \right)  = \mathrm{ \underset{ air }{ p } }\left( 126.85\ \mathrm{°C}, 3.7071\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 518.36\ \mathrm{kPa}
# \end{align}
#
# Pressure ratio
# \begin{align}
#   r_{p} &=  \frac{ {p}_{ 2 } }{ {p}_{ 1 } } \\
#     &= \frac{ 518.36\ \mathrm{kPa} }{ 100.0\ \mathrm{kPa} }\\
#     &= 5.1836
# \end{align}

# %%
pv = air.pv_diagram()

pv.plot_state(states[1])
pv.plot_state(states[2])

pv.plot_process(states[1],states[2],path='isentropic',label='isentropic');

pv.plot_isotherm(T[1],xcoor=.3)
pv.plot_isotherm(T[2],xcoor=.3)
pv.plot_isobar(p[1],pos=0.5)
pv.plot_isobar(p[2],pos=0.5)
pv.plot_isenthalp(air.h(T[2],p[2]));

# %%
Ts = air.Ts_diagram()

Ts.plot_state(states[1],label_loc='north west')
Ts.plot_state(states[2])

Ts.plot_process(states[1],states[2],path='isentropic',label='isentropic');

Ts.plot_isotherm(T[1])
Ts.plot_isotherm(T[2])
Ts.plot_isobar(p[1])
Ts.plot_isobar(p[2],pos=0.5)
Ts.plot_isochor(v[1])
Ts.plot_isochor(v[2],pos=.2);

# %%
# %%showcalc
# Summary();
# Summary(['r','r_p']);
# Out:
# \begin{align}{ r }&={ 3.2335 }&{ r_{p} }&={ 5.1836 }&{  }\end{align}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$T$ [°C]</th>
#       <th>$p$ [kPa]</th>
#       <th>$v$ [m³/kg]</th>
#       <th>$s$ [kJ/K/kg]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>-23.15</td>
#       <td>100.000000</td>
#       <td>0.716943</td>
#       <td>3.70713</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>126.85</td>
#       <td>518.363299</td>
#       <td>0.221721</td>
#       <td>3.70713</td>
#     </tr>
#   </tbody>
# </table>
#
# \begin{align}{ r }&={ 3.2335 }\\{ r_{p} }&={ 5.1836 }\end{align}

# %%
# Export your solution to submit to Canvas
# 1) Ensure all cells above show your final solution
# 2) Click the 'Save' button in the toolbar
# 3) Uncomment (remove the #) from the last line in this cell
# 4) Ensure the filename in the command below matches the filename of this notebook
# 4) Execute this cell to create an HTML file showing only the output 
# 5) Submit the .html file located in the folder with this notebook

# !jupyter nbconvert --to html_embed --no-input --no-prompt "Ex9.1 Isentropic Compression (Real-Fluid).ipynb"
