# %% [markdown]
# # Example 9.2: Otto Cycle (Air-Standard)
#
# *John F. Maddox, Ph.D., P.E.<br>
# University of Kentucky - Paducah Campus<br>
# ME 321: Engineering Thermodynamics II<br>*

# %% [markdown]
# ## Problem Statement
# An Otto cycle with compression ratio of $8$ starts its compression stroke from $p_1=1\ \text{bar}$, $T_1=300\ \text{K}$.  The maximum temperature after combustion is $1200\ \text{K}$.
# Determine:
# * (a) $p$-$v$ diagram
# * (b) $T$-$s$ diagram
# * (c) $T$,$p$ at each state
# * (d) $q_{in}$
# * (e) $w_{net}$
# * (f) $\eta_{th}$

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074244&node=10465167&a=685460354&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_K import *
air = idealgas.Properties('Air', unit_system='SI_C')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
# %%showcalc
# T[1] = Quantity(300,'K')
# p[1] = Quantity(1,'bar')
# T_max = Quantity(1200,'K')
# r = Quantity(8,'')
# Out:
# \begin{align}
#   {T}_{ 1 } &=  300\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 1 } &=  1\ \mathrm{bar}  = 100.0\ \mathrm{kPa}
# \end{align}
#
# \begin{align}
#   T_{max} &=  1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   r &=  8
# \end{align}

# %% [markdown]
# ### Assumptions
#   - Treat air as an ideal gas
#   - Variable Specific Heat

# %%
# %%showcalc
# R = air.R
# Out:
# \begin{align}
#   R &=  \underset{ air }{ R }  = 287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}

# %% [markdown]
# #### (c) $T$,$p$ at each state

# %%
# %%showcalc
# r"Isentropic Compression $1\to2$"
# s[1] = air.s(T[1],p[1])
# v[1] = R*T[1]/p[1]
# v[2] = v[1]/r
# s[2] = s[1]
# T[2] = air.T(s[2],v[2])
# p[2] = air.p(s[2],v[2])
#
# r"Isochoric Heat Addition $2\to3$"
# v[3] = v[2]
# T[3] = T_max
# p[3] = air.p(T=T[3],v=v[3])
#
# r"Isentropic Expansion $3\to4$"
# s[3] = air.s(T[3],v[3])
# s[4] = s[3]
# v[4] = r*v[3]
# T[4] = air.T(v[4],s[4])
# p[4] = air.p(v[4],s[4])
# Out:
# Isentropic Compression $1\to2$
# \begin{align}
#   {s}_{ 1 } &=  \mathrm{ \underset{ air }{ s } }\left( {T}_{ 1 }, {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ s } }\left( 300\ \mathrm{K}, 100.0\ \mathrm{kPa} \right) = 6.7077\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {v}_{ 1 } &=  \frac{  R  \cdot  {T}_{ 1 }  }{ {p}_{ 1 } } \\
#     &= \frac{  287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  \cdot  300\ \mathrm{K}  }{ 100.0\ \mathrm{kPa} }\\
#     &= 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {v}_{ 2 } &=  \frac{ {v}_{ 1 } }{ r } \\
#     &= \frac{ 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 8 }\\
#     &= 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {s}_{ 2 } &=  {s}_{ 1 }  = 6.7077\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {T}_{ 2 } &=  \mathrm{ \underset{ air }{ T } }\left( {s}_{ 2 }, {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ T } }\left( 6.7077\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 672.71\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 2 } &=  \mathrm{ \underset{ air }{ p } }\left( {s}_{ 2 }, {v}_{ 2 } \right)  = \mathrm{ \underset{ air }{ p } }\left( 6.7077\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}, 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 1793.9\ \mathrm{kPa}
# \end{align}
#
# Isochoric Heat Addition $2\to3$
# \begin{align}
#   {v}_{ 3 } &=  {v}_{ 2 }  = 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 3 } &=  T_{max}  = 1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 3 } &=  \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = {T}_{ 3 }, \mathrm{ v } = {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ p } }\left( \mathrm{ T } = 1200\ \mathrm{K}, \mathrm{ v } = 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 3200.0\ \mathrm{kPa}
# \end{align}
#
# Isentropic Expansion $3\to4$
# \begin{align}
#   {s}_{ 3 } &=  \mathrm{ \underset{ air }{ s } }\left( {T}_{ 3 }, {v}_{ 3 } \right)  = \mathrm{ \underset{ air }{ s } }\left( 1200\ \mathrm{K}, 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \right) = 7.1899\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {s}_{ 4 } &=  {s}_{ 3 }  = 7.1899\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   {v}_{ 4 } &=   r  \cdot  {v}_{ 3 }  \\
#     &=  8  \cdot  0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \\
#     &= 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 4 } &=  \mathrm{ \underset{ air }{ T } }\left( {v}_{ 4 }, {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ T } }\left( 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, 7.1899\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 579.52\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 4 } &=  \mathrm{ \underset{ air }{ p } }\left( {v}_{ 4 }, {s}_{ 4 } \right)  = \mathrm{ \underset{ air }{ p } }\left( 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}, 7.1899\ \frac{\mathrm{kJ}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} \right) = 193.17\ \mathrm{kPa}
# \end{align}

# %% [markdown]
# #### (a) $p$-$v$ diagram

# %%
pv = air.pv_diagram()
for i in [1,2,3,4]:
    pv.plot_state(states[i],label_loc='east')
pv.plot_process(states[1],states[2], path='isentropic',label='isentropic',pos=.8)
pv.plot_process(states[2],states[3], path='isochoric')
pv.plot_process(states[3],states[4], path='isentropic',label='isentropic')
pv.plot_process(states[4],states[1], path='isochoric');

pv.plot_isotherm(T[3])
pv.plot_isotherm(T[1],pos=.1);

# %% [markdown]
# #### (b) $T$-$s$ diagram

# %%
Ts = air.Ts_diagram()
for i in [1,2,3,4]:
    Ts.plot_state(states[i], label_loc='north east')
Ts.plot_process(states[1],states[2], path='isentropic')
Ts.plot_process(states[2],states[3], path='isochoric',label='isochoric')
Ts.plot_process(states[3],states[4], path='isentropic')
Ts.plot_process(states[4],states[1], path='isochoric',label='isochoric');

Ts.plot_isobar(p[3],pos=.1)
Ts.plot_isobar(p[1]);

# %% [markdown]
# #### (d) $q_{in}$

# %%
# %%showcalc
# r"Heat transfer only takes place from $2\to3$ and from $4\to1$"
# u[2] = air.u(T[2],p[2])
# u[3] = air.u(T[3],p[3])
#
# q_2_to_3 = u[3]-u[2]
# q_in = q_2_to_3
# Out:
# Heat transfer only takes place from $2\to3$ and from $4\to1$
# \begin{align}
#   {u}_{ 2 } &=  \mathrm{ \underset{ air }{ u } }\left( {T}_{ 2 }, {p}_{ 2 } \right)  = \mathrm{ \underset{ air }{ u } }\left( 672.71\ \mathrm{K}, 1793.9\ \mathrm{kPa} \right) = 188.52\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {u}_{ 3 } &=  \mathrm{ \underset{ air }{ u } }\left( {T}_{ 3 }, {p}_{ 3 } \right)  = \mathrm{ \underset{ air }{ u } }\left( 1200\ \mathrm{K}, 3200.0\ \mathrm{kPa} \right) = 630.51\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{2\to{}3} &=   {u}_{ 3 } - {u}_{ 2 }  \\
#     &=  630.51\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 188.52\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{in} &=  q_{2\to{}3}  = 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (e) $w_{net}$

# %%
# %%showcalc
# r"Heat tranfer from $4\to1$"
# u[1] = air.u(T[1],p[1])
# u[4] = air.u(T[4],p[4])
# q_4_to_1 = u[4]-u[1]
# q_out = q_4_to_1
#
# "First law for the cycle"
# w_net = q_in-q_out
# Out:
# Heat tranfer from $4\to1$
# \begin{align}
#   {u}_{ 1 } &=  \mathrm{ \underset{ air }{ u } }\left( {T}_{ 1 }, {p}_{ 1 } \right)  = \mathrm{ \underset{ air }{ u } }\left( 300\ \mathrm{K}, 100.0\ \mathrm{kPa} \right) = -88.523\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {u}_{ 4 } &=  \mathrm{ \underset{ air }{ u } }\left( {T}_{ 4 }, {p}_{ 4 } \right)  = \mathrm{ \underset{ air }{ u } }\left( 579.52\ \mathrm{K}, 193.17\ \mathrm{kPa} \right) = 116.81\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{4\to{}1} &=   {u}_{ 4 } - {u}_{ 1 }  \\
#     &=  116.81\ \frac{\mathrm{kJ}}{\mathrm{kg}} - \left( -88.523\ \frac{\mathrm{kJ}}{\mathrm{kg}} \right) \\
#     &= 205.33\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{out} &=  q_{4\to{}1}  = 205.33\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}
#
# First law for the cycle
# \begin{align}
#   w_{net} &=   q_{in} - q_{out}  \\
#     &=  442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} - 205.33\ \frac{\mathrm{kJ}}{\mathrm{kg}} \\
#     &= 236.66\ \frac{\mathrm{kJ}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (f)  $\eta_{th}$

# %%
# %%showcalc
# "Thermal efficiency"
# eta_th = w_net/q_in
# Out:
# Thermal efficiency
# \begin{align}
#   \eta_{th} &=  \frac{ w_{net} }{ q_{in} } \\
#     &= \frac{ 236.66\ \frac{\mathrm{kJ}}{\mathrm{kg}} }{ 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\
#     &= 0.53545
# \end{align}

# %% [markdown]
# ## Summary

# %%
# %%showcalc
# Summary()
# Summary(['q_in','w_net','eta_th']);
# Out:
# \begin{align}{ R }&={ 287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} }&{ T_{max} }&={ 1200\ \mathrm{K} }&{ \eta_{th} }&={ 0.53545 }\\{ q_{2\to{}3} }&={ 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{ q_{4\to{}1} }&={ 205.33\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{ q_{in} }&={ 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ q_{out} }&={ 205.33\ \frac{\mathrm{kJ}}{\mathrm{kg}} }&{ r }&={ 8 }&{ w_{net} }&={ 236.66\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\end{align}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$T$ [K]</th>
#       <th>$p$ [kPa]</th>
#       <th>$v$ [m³/kg]</th>
#       <th>$u$ [kJ/kg]</th>
#       <th>$s$ [kJ/K/kg]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>300.000000</td>
#       <td>100.000000</td>
#       <td>0.861158</td>
#       <td>-88.522932</td>
#       <td>6.707703</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>672.711591</td>
#       <td>1793.897575</td>
#       <td>0.107645</td>
#       <td>188.517390</td>
#       <td>6.707703</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1200.000000</td>
#       <td>3200.000000</td>
#       <td>0.107645</td>
#       <td>630.512803</td>
#       <td>7.189908</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>579.518321</td>
#       <td>193.172774</td>
#       <td>0.861158</td>
#       <td>116.808103</td>
#       <td>7.189908</td>
#     </tr>
#   </tbody>
# </table>
#
# \begin{align}{ q_{in} }&={ 442.0\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ w_{net} }&={ 236.66\ \frac{\mathrm{kJ}}{\mathrm{kg}} }\\{ \eta_{th} }&={ 0.53545 }\end{align}

# %%
# Export your solution to submit to Canvas
# 1) Ensure all cells above show your final solution
# 2) Click the 'Save' button in the toolbar
# 3) Uncomment (remove the #) from the last line in this cell
# 4) Ensure the filename in the command below matches the filename of this notebook
# 4) Execute this cell to create an HTML file showing only the output 
# 5) Submit the .html file located in the folder with this notebook

# !jupyter nbconvert --to html_embed --no-input --no-prompt "Ex9.2 Otto Cycle (Air-Standard).ipynb"
