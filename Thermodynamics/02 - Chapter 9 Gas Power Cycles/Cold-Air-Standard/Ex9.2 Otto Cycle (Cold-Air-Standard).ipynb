# %% [markdown]
# # Example 9.2: Otto Cycle (Cold-Air-Standard)
#
# *John F. Maddox, Ph.D., P.E.<br>
# University of Kentucky - Paducah Campus<br>
# ME 321: Engineering Thermodynamics II<br>*

# %% [markdown]
# ## Problem Statement
# An Otto cycle with compression ratio of $8$ starts its compression stroke from $p_1=1\ \text{bar}$, $T_1=300\ \text{K}$.  The maximum temperature after combustion is $1200\ \text{K}$.
# Determine:
# * (a) $p$-$v$ diagram
# * (b) $T$-$s$ diagram
# * (c) $T$,$p$ at each state
# * (d) $q_{in}$
# * (e) $w_{net}$
# * (f) $\eta_{th}$

# %% [markdown]
# ## Solution
#
# __[Video Explanation](https://uky.yuja.com/V/Video?v=3074244&node=10465167&a=685460354&autoplay=1)__

# %% [markdown]
# ### Python Initialization
# We'll start by importing the libraries we will use for our analysis and initializing dictionaries to hold the properties we will be usings.

# %%
from kilojoule.templates.kSI_K import * 
air = idealgas.Properties('Air', unit_system='SI_K')

# %% [markdown]
# ### Given Parameters
# We now define variables to hold our known values.

# %%
# %%showcalc
# T[1] = Quantity(300,'K')
# p[1] = Quantity(1,'bar')
# T_max = Quantity(1200,'K')
# r = Quantity(8,'')
# Out:
# \begin{align}
#   {T}_{ 1 } &=  300\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 1 } &=  1\ \mathrm{bar}  = 100.0\ \mathrm{kPa}
# \end{align}
#
# \begin{align}
#   T_{max} &=  1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   r &=  8
# \end{align}

# %% [markdown]
# ### Assumptions
#   - Treat air as an ideal gas
#   - Variable Specific Heat

# %%
# %%showcalc
# "Ideal Gas"
# R = air.R
#
# "Constant thermal properties at room temperature"
# T_room = Quantity(300,'degC')
# c_p = air.Cp(T=T_room)
# c_v = air.Cv(T=T_room)
# k = air.k(T=T_room)
# Out:
# Ideal Gas
# \begin{align}
#   R &=  \underset{ air }{ R }  = 287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# Constant thermal properties at room temperature
# \begin{align}
#   T_{room} &=  300\ \mathrm{°C}
# \end{align}
#
# \begin{align}
#   c_{p} &=  \mathrm{ \underset{ air }{ Cp } }\left( \mathrm{ T } = T_{room} \right)  = \mathrm{ \underset{ air }{ Cp } }\left( \mathrm{ T } = 300\ \mathrm{°C} \right) = 1044.6\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   c_{v} &=  \mathrm{ \underset{ air }{ Cv } }\left( \mathrm{ T } = T_{room} \right)  = \mathrm{ \underset{ air }{ Cv } }\left( \mathrm{ T } = 300\ \mathrm{°C} \right) = 757.52\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}
# \end{align}
#
# \begin{align}
#   k &=  \mathrm{ \underset{ air }{ k } }\left( \mathrm{ T } = T_{room} \right)  = \mathrm{ \underset{ air }{ k } }\left( \mathrm{ T } = 300\ \mathrm{°C} \right) = 1.3789
# \end{align}

# %% [markdown]
# #### (c) $T$,$p$ at each state

# %%
# %%showcalc
# r"Isentropic Compression $1\to2$"
# v[1] = R*T[1]/p[1]
# v[2] = v[1]/r
# r"Isentropic Ideal Gas Relations"
# T[2] = T[1]*(v[1]/v[2])**(k-1)
# p[2] = T[2]*R/v[2]
#
# r"Isochoric Heat Addition $2\to3$"
# v[3] = v[2]
# T[3] = T_max
# p[3] = T[3]*R/v[3]
#
# r"Isentropic Expansion $3\to4$"
# v[4] = r*v[3]
# T[4] = T[3]*(v[3]/v[4])**(k-1)
# p[4] = T[4]*R/v[4]
# Out:
# Isentropic Compression $1\to2$
# \begin{align}
#   {v}_{ 1 } &=  \frac{  R  \cdot  {T}_{ 1 }  }{ {p}_{ 1 } } \\
#     &= \frac{  287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  \cdot  300\ \mathrm{K}  }{ 100.0\ \mathrm{kPa} }\\
#     &= 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {v}_{ 2 } &=  \frac{ {v}_{ 1 } }{ r } \\
#     &= \frac{ 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 8 }\\
#     &= 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# Isentropic Ideal Gas Relations
# \begin{align}
#   {T}_{ 2 } &=   {T}_{ 1 }  \cdot  {\left(\frac{ {v}_{ 1 } }{ {v}_{ 2 } }\right)}^{\left( k - 1 \right)}  \\
#     &=  300\ \mathrm{K}  \cdot  {\left(\frac{ 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\right)}^{\left( 1.3789 - 1 \right)} \\
#     &= 659.68\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 2 } &=  \frac{  {T}_{ 2 }  \cdot  R  }{ {v}_{ 2 } } \\
#     &= \frac{  659.68\ \mathrm{K}  \cdot  287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }{ 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\\
#     &= 1759.1\ \mathrm{kPa}
# \end{align}
#
# Isochoric Heat Addition $2\to3$
# \begin{align}
#   {v}_{ 3 } &=  {v}_{ 2 }  = 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 3 } &=  T_{max}  = 1200\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 3 } &=  \frac{  {T}_{ 3 }  \cdot  R  }{ {v}_{ 3 } } \\
#     &= \frac{  1200\ \mathrm{K}  \cdot  287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }{ 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\\
#     &= 3200.0\ \mathrm{kPa}
# \end{align}
#
# Isentropic Expansion $3\to4$
# \begin{align}
#   {v}_{ 4 } &=   r  \cdot  {v}_{ 3 }  \\
#     &=  8  \cdot  0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} \\
#     &= 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   {T}_{ 4 } &=   {T}_{ 3 }  \cdot  {\left(\frac{ {v}_{ 3 } }{ {v}_{ 4 } }\right)}^{\left( k - 1 \right)}  \\
#     &=  1200\ \mathrm{K}  \cdot  {\left(\frac{ 0.10764\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }{ 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\right)}^{\left( 1.3789 - 1 \right)} \\
#     &= 545.72\ \mathrm{K}
# \end{align}
#
# \begin{align}
#   {p}_{ 4 } &=  \frac{  {T}_{ 4 }  \cdot  R  }{ {v}_{ 4 } } \\
#     &= \frac{  545.72\ \mathrm{K}  \cdot  287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  }{ 0.86116\ \frac{\mathrm{m}^{3}}{\mathrm{kg}} }\\
#     &= 181.91\ \mathrm{kPa}
# \end{align}

# %% [markdown]
# ### Plotting
# *Note: The plotting library using the property tables to draw the process paths, which inherently assumes variable specific heat (i.e. real-fluid or air-standard assumptions).  If the library is used to draw process paths between states that were obtained using constant specific heat (cold-air-standard assumptions) there will be inconsistencies between the state points and the process paths.*
#
# In order to plot the paths of the cycle on the $p$-$v$ diagram and states on the $T$-$s$ diagram, we need discrete values for the specifc enthalpy and entropy at each state rather than just the changes in properties we calculated above.  To do this, we will use the variable specific heat tables for the other properties to enable us to draw the paths.  The isentropic lines do not line up exactly with the states in this diagram because the entropies were calculated for variable specific heat, but all other properties were calculated using the
# cold-air-standard assumptions (constant specific heat).

# %% [markdown]
# #### $p$-$v$ diagram

# %%
pv = air.pv_diagram()
from math import log

for i in [1,2,3,4]:
    h[i] = air.h(T=T[i])
    s[i] = air.s(T=T[i],p=p[i])

for i in [1,2,3,4]:
    pv.plot_state(states[i],label_loc='east')
    
pv.plot_process(states[1],states[2],path='isentropic')
pv.plot_process(states[2],states[3],path='isochoric')
pv.plot_process(states[3],states[4],path='isentropic')
pv.plot_process(states[4],states[1],path='isochoric');

# %% [markdown]
# #### (b) $T$-$s$ diagram
# **Note: the isentropic lines are not vertical in this diagram because the entropies were
# calculated for variable specific heat**, but all other properties were calculated using the
# cold-air-standard assumptions (constant specific heat).  Therefore the errors resulting from the constant specific heat assumption are evident in the skewed shape of the cycle on the $T$-$s$ diagram.

# %%
Ts = air.Ts_diagram()

for i in [1,2,3,4]:
    Ts.plot_state(states[i], label_loc='north east')

Ts.plot_process(states[1],states[2],label='incorrect trend',path='isentropic')
Ts.plot_process(states[2],states[3],path='isochoric')
Ts.plot_process(states[3],states[4],label='incorrect trend',path='isentropic')
Ts.plot_process(states[4],states[1],path='isochoric');

# %% [markdown]
# #### (d) $q_{in}$

# %%
# %%showcalc
# r"Heat transfer only takes place from $2\to3$ and from $4\to1$"
# "First Law from 2 to 3 to find the heat input"
# q_2_to_3 = c_v*(T[3]-T[2])
# q_in = q_2_to_3
# Out:
# Heat transfer only takes place from $2\to3$ and from $4\to1$
# First Law from 2 to 3 to find the heat input
# \begin{align}
#   q_{2\to{}3} &=   c_{v}  \cdot  \left(  {T}_{ 3 } - {T}_{ 2 }  \right)  \\
#     &=  757.52\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  \cdot  \left(  1200\ \mathrm{K} - 659.68\ \mathrm{K}  \right) \\
#     &= 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{in} &=  q_{2\to{}3}  = 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (e) $w_{net}$

# %%
# %%showcalc
# "First Law from 4 to 1 to find the heat rejection"
# q_4_to_1 = c_v*(T[4]-T[1])
# q_out = q_4_to_1
#
# "First Law for the cycle"
# w_net = q_in-q_out
# Out:
# First Law from 4 to 1 to find the heat rejection
# \begin{align}
#   q_{4\to{}1} &=   c_{v}  \cdot  \left(  {T}_{ 4 } - {T}_{ 1 }  \right)  \\
#     &=  757.52\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)}  \cdot  \left(  545.72\ \mathrm{K} - 300\ \mathrm{K}  \right) \\
#     &= 1.8614\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}}
# \end{align}
#
# \begin{align}
#   q_{out} &=  q_{4\to{}1}  = 1.8614\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}}
# \end{align}
#
# First Law for the cycle
# \begin{align}
#   w_{net} &=   q_{in} - q_{out}  \\
#     &=  4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} - 1.8614\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} \\
#     &= 2.2317\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}}
# \end{align}

# %% [markdown]
# #### (f)  $\eta_{th}$

# %%
# %%showcalc
# "Thermal efficiency"
# eta_th = w_net/q_in
# Out:
# Thermal efficiency
# \begin{align}
#   \eta_{th} &=  \frac{ w_{net} }{ q_{in} } \\
#     &= \frac{ 2.2317\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }{ 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }\\
#     &= 0.54523
# \end{align}

# %%
Summary(show=True)
Summary(['q_in','w_net','eta_th'],show=True);
# Out:
# \begin{align}{ R }&={ 287.05\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} }&{ T_{max} }&={ 1200\ \mathrm{K} }&{ T_{room} }&={ 300\ \mathrm{°C} }\\{ c_{p} }&={ 1044.6\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} }&{ c_{v} }&={ 757.52\ \frac{\mathrm{J}}{\left(\mathrm{K} \cdot \mathrm{kg}\right)} }&{ \eta_{th} }&={ 0.54523 }\\{ k }&={ 1.3789 }&{ q_{2\to{}3} }&={ 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }&{ q_{4\to{}1} }&={ 1.8614\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }\\{ q_{in} }&={ 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }&{ q_{out} }&={ 1.8614\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }&{ r }&={ 8 }\\{ w_{net} }&={ 2.2317\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }&{  }\end{align}
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>$T$ [K]</th>
#       <th>$p$ [kPa]</th>
#       <th>$v$ [m³/kg]</th>
#       <th>$h$ [kJ/kg]</th>
#       <th>$s$ [kJ/K/kg]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>300.000000</td>
#       <td>100.000000</td>
#       <td>0.861158</td>
#       <td>-2.407134</td>
#       <td>6.707703</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>659.680798</td>
#       <td>1759.148794</td>
#       <td>0.107645</td>
#       <td>367.731665</td>
#       <td>6.692467</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1200.000000</td>
#       <td>3200.000000</td>
#       <td>0.107645</td>
#       <td>974.975994</td>
#       <td>7.189908</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>545.718477</td>
#       <td>181.906159</td>
#       <td>0.861158</td>
#       <td>247.929153</td>
#       <td>7.144521</td>
#     </tr>
#   </tbody>
# </table>
# \begin{align}{ q_{in} }&={ 4.093\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }\\{ w_{net} }&={ 2.2317\times 10^{5}\ \frac{\mathrm{J}}{\mathrm{kg}} }\\{ \eta_{th} }&={ 0.54523 }\end{align}

# %%
# Export your solution to submit to Canvas
# 1) Ensure all cells above show your final solution
# 2) Click the 'Save' button in the toolbar
# 3) Uncomment (remove the #) from the last line in this cell
# 4) Ensure the filename in the command below matches the filename of this notebook
# 4) Execute this cell to create an HTML file showing only the output 
# 5) Submit the .html file located in the folder with this notebook

# !jupyter nbconvert --to html_embed --no-input --no-prompt "Ex9.2 Otto Cycle (Cold-Air-Standard).ipynb"
